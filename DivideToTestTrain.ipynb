# %%
import pandas as pd
from sklearn.model_selection import train_test_split
import numpy as np
import random
import operator
import math

# %%
df = pd.read_csv("Replaced.csv",encoding="ISO-8859-1")

# %%
df.to_csv("data.csv",encoding="UTF-8")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'brand', 'categories', 'dateAdded', 'dateUpdated',
#        'ean', 'keys', 'manufacturer', 'manufacturerNumber', 'name',
#        'reviewsdate', 'dateSeen', 'didPurchase', 'doRecommend', 'reviews_id',
#        'reviews.numHelpful', 'rating', 'sourceURLs', 'text', 'title',
#        'userCity', 'userProvince', 'username', 'upc'],
#       dtype='object')

# %%
def get_hash(x):
  return abs(hash(x)) % 10**9
df['username'] = df['username'].apply(get_hash)
df['id'] = df['id'].apply(get_hash)

# %%
df.head()
# Out:
#    Unnamed: 0         id            brand  \
# 0           0  485923821  Universal Music
# 1           1  699359163         Lundberg
# 2           2  699359163         Lundberg
# 3           3  280166477              K-Y
# 4           4  280166477              K-Y
#
#                                           categories             dateAdded  \
# 0  Movies, Music & Books,Music,R&b,Movies & TV,Mo...  2017-07-25T00:52:42Z
# 1  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 2  Food,Packaged Foods,Snacks,Crackers,Snacks, Co...  2017-07-25T05:16:03Z
# 3  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
# 4  Personal Care,Medicine Cabinet,Lubricant/Sperm...  2017-07-25T16:26:19Z
#
#             dateUpdated          ean  \
# 0  2018-02-05T08:36:58Z     6.03E+11
# 1  2018-02-05T11:27:45Z  73416000391
# 2  2018-02-05T11:27:45Z  73416000391
# 3  2018-02-05T11:25:51Z  67981934427
# 4  2018-02-05T11:25:51Z  67981934427
#
#                                                 keys  \
# 0  602537205981,universalmusic/14331328,universal...
# 1  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 2  lundbergorganiccinnamontoastricecakes/b000fvzw...
# 3  kylovesensualitypleasuregel/b00u2whx8s,0679819...
# 4  kylovesensualitypleasuregel/b00u2whx8s,0679819...
#
#                          manufacturer manufacturerNumber     ...       \
# 0  Universal Music Group / Cash Money           14331328     ...
# 1                            Lundberg             574764     ...
# 2                            Lundberg             574764     ...
# 3                                 K-Y        67981934427     ...
# 4                                 K-Y        67981934427     ...
#
#     reviews_id reviews.numHelpful rating  \
# 0          NaN                0.0      5
# 1  100209113.0                NaN      5
# 2  100209113.0                NaN      5
# 3  113026909.0                NaN      1
# 4  171267657.0                NaN      1
#
#                                           sourceURLs  \
# 0  https://redsky.target.com/groot-domain-api/v1/...
# 1   https://www.walmart.com/reviews/product/29775278
# 2   https://www.walmart.com/reviews/product/29775278
# 3   https://www.walmart.com/reviews/product/43383370
# 4   https://www.walmart.com/reviews/product/43383370
#
#                                                 text         title  userCity  \
# 0  i love this album. it's very good. more to the...  Just Awesome     Japan
# 1  Good flavor. This review was collected as part...          Good     Japan
# 2                                       Good flavor.          Good   America
# 3  I read through the reviews on here before look...  Disappointed     China
# 4  My husband bought this gel for us. The gel cau...    Irritation     China
#
#    userProvince   username          upc
# 0           NaN  283138599     6.03E+11
# 1           NaN  338802773  73416000391
# 2           NaN  338802773  73416000391
# 3           NaN  537324623  67981934427
# 4           NaN  600608368  67981934427
#
# [5 rows x 25 columns]

# %%
y = df.rating

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'id', 'brand', 'categories', 'dateAdded', 'dateUpdated',
#        'ean', 'keys', 'manufacturer', 'manufacturerNumber', 'name',
#        'reviewsdate', 'dateSeen', 'didPurchase', 'doRecommend', 'reviews_id',
#        'reviews.numHelpful', 'rating', 'sourceURLs', 'text', 'title',
#        'userCity', 'userProvince', 'username', 'upc'],
#       dtype='object')

# %%
y.head()
# Out:
# 0    5
# 1    5
# 2    5
# 3    1
# 4    1
# Name: rating, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y,test_size=0.2)
print ("\nX_train:\n")
print(X_train.head())
print (X_train.shape)
print ("\nX_test:\n")
print(X_test.head())
print (X_test.shape)
# Out:
# X_train:
#
#        Unnamed: 0         id              brand  \
# 33641       33668  824085496             Disney
# 25378       25395  646672850  Warner Home Video
# 50575       50608  114557595               Tide
# 47514       47547  246140130         Neutrogena
# 26556       26573  133127652               Ragu
#
#                                               categories  \
# 33641  Movies, Music & Books,Ways To Shop Entertainme...
# 25378  Movies, Music & Books,Movies,Action & Adventur...
# 50575  Household Essentials,Ways To Shop,Household Es...
# 47514  Personal Care,Medicine Cabinet,Skin Fading/Lig...
# 26556  Food,Packaged Foods,Condiments, Dips, & Salad ...
#
#                   dateAdded           dateUpdated          ean  \
# 33641  2016-12-28T22:31:24Z  2018-02-05T08:36:37Z          NaN
# 25378  2016-07-26T21:32:40Z  2018-02-05T10:22:44Z          NaN
# 50575  2015-10-29T11:28:10Z  2018-02-05T08:35:12Z          NaN
# 47514  2015-11-06T13:51:37Z  2018-02-05T11:28:49Z          NaN
# 26556  2015-10-23T06:36:30Z  2018-02-05T11:25:54Z  36200014011
#
#                                                     keys      manufacturer  \
# 33641  786936850628,disney/50978083,junglebookblurayd...       Buena Vista
# 25378  warnerhomevideo/15773884,883929388448,godzilla...              Test
# 50575  037000138822,tide/13918059,tideoriginalscentli...  Procter & Gamble
# 47514  070501110362,neutrogenarapidtonerepairdarkspot...        Neutrogena
# 26556  ragutraditionalpastasauce/b0035n3ads,ragutradi...          Unilever
#
#       manufacturerNumber               ...                 reviews_id  \
# 33641           50978083               ...                        NaN
# 25378           15773884               ...                        NaN
# 50575           13918059               ...                        NaN
# 47514           14953560               ...                 97088378.0
# 26556           12935361               ...                107524410.0
#
#       reviews.numHelpful rating  \
# 33641                0.0      5
# 25378                0.0      5
# 50575                NaN      5
# 47514                NaN      5
# 26556                0.0      5
#
#                                               sourceURLs  \
# 33641  http://reviews.bestbuy.com/3545/5094600/review...
# 25378  http://reviews.bestbuy.com/3545/6435036/review...
# 50575  https://redsky.target.com/groot-domain-api/v1/...
# 47514  https://www.walmart.com/reviews/product/350433...
# 26556   https://www.walmart.com/reviews/product/10291073
#
#                                                     text  \
# 33641  Visually this is fantastic & it stays true to ...
# 25378  Finally! A Godzilla movie that was made true t...
# 50575  Waited until I washed my husbands white dress ...
# 47514  Riding through the desert with cowboys, and ju...
# 26556  This is how i like my sauce, if i want eat veg...
#
#                                                    title  userCity  \
# 33641              The live action version of a classic.        UK
# 25378  The best Godzilla movie we have been waiting for!        UK
# 50575                                         Impressed!     China
# 47514                                     Turn Back Time     China
# 26556                     This is great sauxce and cheap     Japan
#
#        userProvince   username                             upc
# 33641           NaN  539861276                        7.87E+11
# 25378           NaN  585122015                        8.84E+11
# 50575           NaN  647011901                     37000138822
# 47514           NaN  116075470  70,501,110,362,885,100,000,000
# 26556           NaN  555800904                     36200014011
#
# [5 rows x 25 columns]
# (56802, 25)
#
# X_test:
#
#        Unnamed: 0         id      brand  \
# 1071         1071  838792912       KIND
# 19574       19588  260262498     Clorox
# 55334       55368  936839005  Lionsgate
# 34025       34052  824085496     Disney
# 50547       50580  114557595       Tide
#
#                                               categories  \
# 1071   Food,Packaged Foods,Snacks,Cereal Bars and Gra...
# 19574  Household Chemicals,Household Cleaners,Bath & ...
# 55334  Movies, Music & Books,Movies,Romance,Movies & ...
# 34025  Movies, Music & Books,Ways To Shop Entertainme...
# 50547  Household Essentials,Ways To Shop,Household Es...
#
#                   dateAdded           dateUpdated          ean  \
# 1071   2017-07-19T02:01:37Z  2018-02-05T11:26:49Z     6.03E+11
# 19574  2016-04-06T12:31:21Z  2018-02-05T11:26:19Z  44600080338
# 55334  2015-08-31T20:34:45Z  2018-02-05T08:36:40Z          NaN
# 34025  2016-12-28T22:31:24Z  2018-02-05T08:36:37Z          NaN
# 50547  2015-10-29T11:28:10Z  2018-02-05T08:35:12Z          NaN
#
#                                                     keys  \
# 1071   602652184024,kind/15027059,darkchocolatechunkg...
# 19574  044600080338,cloroxdisinfectingbathroomcleaner...
# 55334  013132597218,lionsgate/14516230,anchorbayenter...
# 34025  786936850628,disney/50978083,junglebookblurayd...
# 50547  037000138822,tide/13918059,tideoriginalscentli...
#
#                    manufacturer manufacturerNumber  \
# 1071      Kind Fruit & Nut Bars           15027059
# 19574            AmazonUs/CLOO7           13028043
# 55334  Anchor Bay Entertainment           14516230
# 34025               Buena Vista           50978083
# 50547          Procter & Gamble           13918059
#
#                     ...                reviews_id reviews.numHelpful rating  \
# 1071                ...                63573292.0                0.0      5
# 19574               ...                41180396.0                NaN      5
# 55334               ...                       NaN                0.0      5
# 34025               ...                       NaN                0.0      5
# 50547               ...                       NaN                NaN      5
#
#                                               sourceURLs  \
# 1071    https://www.walmart.com/reviews/product/34202687
# 19574  https://www.walmart.com/reviews/product/254837...
# 55334  http://reviews.bestbuy.com/3545/8798007/review...
# 34025  http://reviews.bestbuy.com/3545/5094600/review...
# 50547  https://redsky.target.com/groot-domain-api/v1/...
#
#                                                     text               title  \
# 1071   I eat these when I want something a little swe...  I love these bars!
# 19574  I have a personal use for them, for the elderl...         give it a 5
# 55334  This was a really good movie with a lot of cha...       AWESOME MOVIE
# 34025  Movie was great lots of emotion beautiful pict...         Great movie
# 50547  Love the smell washes very well. Have used tid...       Good Old Tide
#
#         userCity  userProvince   username                             upc
# 1071   Australia           NaN  597805296                        6.03E+11
# 19574  Australia           NaN  895941682  44,600,080,338,044,600,000,000
# 55334      Japan           NaN  388693832                     13132597218
# 34025      India           NaN  919467472                        7.87E+11
# 50547      China           NaN  318344685                     37000138822
#
# [5 rows x 25 columns]
# (14201, 25)

# %%
X_train.to_csv("training.csv",encoding="UTF-8")

# %%
X_test.to_csv("test.csv",encoding="UTF-8")

# %%
df_features = df.drop(df['rating'])

# %%
# Number of Attributes
num_attr = len(df_features.columns) - 1

# Number of Clusters
k = 2

# Maximum number of iterations
MAX_ITER = 100

# Number of data points
n = len(df)

# Fuzzy parameter
m = 2.00

# %%
def initializeMembershipMatrix():
    membership_mat = list()
    for i in range(n):
        random_num_list = [random.random() for i in range(k)]
        summation = sum(random_num_list)
        temp_list = [x/summation for x in random_num_list]
        membership_mat.append(temp_list)
    return membership_mat

# %%
def calculateClusterCenter(membership_mat):
    cluster_mem_val = zip(*membership_mat)
    cluster_centers = list()
    for j in range(k):
        next(zip(*ngram))
        x = list(cluster_mem_val[j])
        xraised = [e ** m for e in x]
        denominator = sum(xraised)
        temp_num = list()
        for i in range(n):
            data_point = list(df.iloc[i])
            prod = [xraised[i] * val for val in data_point]
            temp_num.append(prod)
        numerator = map(sum, zip(*temp_num))
        center = [z/denominator for z in numerator]
        cluster_centers.append(center)
    return cluster_centers

# %%
def updateMembershipValue(membership_mat, cluster_centers):
    p = float(2/(m-1))
    for i in range(n):
        x = list(df.iloc[i])
        distances = [np.linalg.norm(map(operator.sub, x, cluster_centers[j])) for j in range(k)]
        for j in range(k):
            den = sum([math.pow(float(distances[j]/distances[c]), p) for c in range(k)])
            membership_mat[i][j] = float(1/den)       
    return membership_mat

# %%
def getClusters(membership_mat):
    cluster_labels = list()
    for i in range(n):
        max_val, idx = max((val, idx) for (idx, val) in enumerate(membership_mat[i]))
        cluster_labels.append(idx)
    return cluster_labels

# %%
def fuzzyCMeansClustering():
    # Membership Matrix
    membership_mat = initializeMembershipMatrix()
    curr = 0
    while curr <= MAX_ITER:
        cluster_centers = calculateClusterCenter(membership_mat)
        membership_mat = updateMembershipValue(membership_mat, cluster_centers)
        cluster_labels = getClusters(membership_mat)
        curr += 1
    print(membership_mat)
    return cluster_labels, cluster_centers

# %%
labels, centers = fuzzyCMeansClustering()
a,p,r = accuracy(labels, class_labels)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-cb654a571464> in <module>()
# ----> 1 labels, centers = fuzzyCMeansClustering()
#       2 a,p,r = accuracy(labels, class_labels)
#
# <ipython-input-20-1c38995e43fa> in fuzzyCMeansClustering()
#       4     curr = 0
#       5     while curr <= MAX_ITER:
# ----> 6         cluster_centers = calculateClusterCenter(membership_mat)
#       7         membership_mat = updateMembershipValue(membership_mat, cluster_centers)
#       8         cluster_labels = getClusters(membership_mat)
#
# <ipython-input-17-b5891f9fdbd4> in calculateClusterCenter(membership_mat)
#       3     cluster_centers = list()
#       4     for j in range(k):
# ----> 5         x = list(cluster_mem_val[j])
#       6         xraised = [e ** m for e in x]
#       7         denominator = sum(xraised)
#
# TypeError: 'zip' object is not subscriptable
